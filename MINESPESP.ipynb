# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - 1.17
# - 1.16.5
# - 1.16.4
# - 1.16.3
# - 1.15.2
# - 1.14.4
# - 1.13.2
# - 1.12.2
# - 1.11.2
# - 1.10.2
# - 1.9.4
# - 1.8.8


version = '1.20.1' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit)

server_type = 'mohist'

#Importa librerias necesarias para el funcionamiento del script

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

if server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

if server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

if server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version
if server_type == 'fabric':
    serverURL = 'https://maven.fabricmc.net/net/fabricmc/fabric-installer/0.11.2/fabric-installer-0.11.2.jar'

if server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version

jar_name = {'paper': 'server.jar', 'fabric': 'fabric-installer.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-installer.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# Descargando el tipo de servidor:
# Descargando a GitHub Codespaces...
# Completado!

# %%
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading



#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)



# Instalar OpenJDK


version = colabconfig["server_version"]

if colabconfig["server_version"] < "1.17":

    # !sudo apt-get purge openjdk* > /dev/null 2>&1

    # !sudo apt-get install openjdk-8-jre-headless &>/dev/null and print("OpenJDK 8 instalado!") or print("Error al intalar OpenJDK 8.")

else:

    # !sudo apt-get purge openjdk* > /dev/null 2>&1

    # !sudo apt-get install openjdk-17-jre-headless &>/dev/null and print("OpenJDK 17 instalado!") or print("Error al intalar OpenJDK 17.")


# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

if java_ver[0] == "17":

    print("Estas usando JAVA 17.")

else:

    print("Estas usando una version desactualizada de java. Puedo que Minecraft 1.17+ no funcione.")



#Lista de posibles archivos .jar


jar_list = {'paper': 'server.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar"}

jar_name = jar_list[colabconfig["server_type"]]



# Java arguments.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2cxc8NeoT0DMl0sNPWBHA9JmbTw_6dUpRyh1Ge2iTL7B5RXeA" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))



print('Iniciando servidor...')

def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

if colabconfig["server_type"] == "forge":

    version = colabconfig["server_version"]

    if colabconfig["server_version"] < "1.17":

        oldpathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/forge-{version}-*.jar")

        if oldpathtoforge: # Checa si la lista no esta vacia

            path = oldpathtoforge[0] # Obtiene la primera ruta de la lista

            print(path)

            # !java $memory_allocation -jar "{path}" nogui

        else:

            print("No se encontro la version de Forge universal.")

    else:

        pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{version}-/unix_.txt")

        if pathtoforge: # Checa si la lista no esta vacia

            path = pathtoforge[0] # Obtiene la primera ruta de la lista

            print(path)

            # !java @user_jvm_args.txt "@{path}" "$@"

        else:

            print("No unix_args.txt found.")
else:

    # !java $memory_allocation $server_flags -jar $jar_name nogui



# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)
# Out:
# el apt cache fue actualizado correctamente
# banned-ips.json      even	    mohist-config      spigot.yml
# banned-players.json  event	    mohist.jar	       user_jvm_args.txt
# bukkit.yml	     forge.jar	    ops.json	       usercache.json
# colabconfig.json     forge.jar.log  permissions.yml    usernamecache.json
# commands.yml	     help.yml	    plugins	       wepif.yml
# config		     libraries	    run.bat	       whitelist.json
# defaultconfigs	     logs	    run.sh	       world
# eula.txt	     mods	    server.properties
# /bin/bash: -c: line 0: syntax error near unexpected token `('
# /bin/bash: -c: line 0: `sudo apt-get install openjdk-17-jre-headless &>/dev/null and print("OpenJDK 17 instalado!") or print("Error al intalar OpenJDK 17.")'
# Estas usando una version desactualizada de java. Puedo que Minecraft 1.17+ no funcione.
# Usando ngrok
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# La IP de tu servidor es 8.tcp.ngrok.io:12262
# Iniciando servidor...
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
#
#  ███╗   ███╗  ██████╗  ██╗  ██╗ ██╗ ███████╗ ████████╗
#  ████╗ ████║ ██╔═══██╗ ██║  ██║ ██║ ██╔════╝ ╚══██╔══╝
#  ██╔████╔██║ ██║   ██║ ███████║ ██║ ███████╗    ██║
#  ██║╚██╔╝██║ ██║   ██║ ██╔══██║ ██║ ╚════██║    ██║
#  ██║ ╚═╝ ██║ ╚██████╔╝ ██║  ██║ ██║ ███████║    ██║
#  ╚═╝     ╚═╝  ╚═════╝  ╚═╝  ╚═╝ ╚═╝ ╚══════╝    ╚═╝
#
#
# Thanks for using Mohist - 1.20.1-580, Java(21.0.2) 65.0 PID: 77704
#
# Update in check...
# If you don't want to enable update check, set check_update in mohist-config/mohist.yml to false
# The latest Mohist version is 1.20.1-585 but you have 1.20.1-580. The latest version has been built on 2024-02-27 09:36:34. You should update to fix recent bugs!
# Checking libraries, please wait...
# All libraries are nice :)!
# Searching incompatible mods...
# [02:14:27 INFO]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 47.2.20, --fml.mcVersion, 1.20.1, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20230612.114412, nogui]
# [02:14:27 INFO]: ModLauncher 10.0.9+10.0.9+main.dcd20f30 starting: java version 21.0.2 by Microsoft; OS Linux arch amd64 version 6.2.0-1019-azure
# [02:14:27 INFO]: ImmediateWindowProvider not loading because launch target is forgeserver
# [02:14:27 INFO]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%23111!/ Service=ModLauncher Env=SERVER
# [02:14:27 INFO]: No dependencies to load found. Skipping!
# [02:14:29 INFO]: Launching target 'forgeserver' with arguments [nogui]
# [02:14:34 INFO]: Forge mod loading, version 47.2.20, for MC 1.20.1 with MCP 20230612.114412
# [02:14:34 INFO]: MinecraftForge v47.2.20 Initialized
# [02:14:34 INFO]: NeoForge v47.2.20 Initialized
# [02:14:34 INFO]: Mohist mod loading.....
# [02:14:34 INFO]: EventDispatcherRegistry initialized
# [02:14:35 INFO]: [voicechat] Compatibility version 18
# [02:14:35 INFO]: [voicechat] Loading plugins
# [02:14:35 INFO]: [voicechat] Loaded 0 plugin(s)
# [02:14:35 INFO]: [voicechat] Initializing plugins
# [02:14:35 INFO]: [voicechat] Initialized 0 plugin(s)
# [02:14:36 INFO]: Environment: authHost='https://authserver.mojang.com', accountsHost='https://api.mojang.com', sessionHost='https://sessionserver.mojang.com', servicesHost='https://api.minecraftservices.com', name='PROD'
# [02:14:38 INFO]: Loaded 7 recipes
# [02:14:38 INFO]: Loaded 1271 advancements
# [02:14:39 INFO]: Starting minecraft server version 1.20.1
# [02:14:39 INFO]: Loading properties
# [02:14:39 INFO]: Default game type: SURVIVAL
# [02:14:39 INFO]: Generating keypair
# 1h=> [02:14:39 INFO]: Starting Minecraft server on *:25565
# [02:14:39 INFO]: Using epoll channel type
# [02:14:39 WARN]: **** SERVER IS RUNNING IN OFFLINE/INSECURE MODE!
# [02:14:39 WARN]: The server will make no attempt to authenticate usernames. Beware.
# [02:14:39 WARN]: While this makes the game possible to play without internet access, it also opens up the ability for hackers to connect with any username they choose.
# [02:14:39 WARN]: To change this, set "online-mode" to "true" in the server.properties file.
# [02:14:39 INFO]: This server is running Mohist version 1.20.1-580 (MC: 1.20.1) (Implementing API version 1.20.1-R0.1-SNAPSHOT, Forge version 47.2.20, NeoForge version 47.1.79)
# [02:14:40 INFO]: Debug logging is enabled
# [02:14:40 INFO]: Server Ping Player Sample Count: 20
# [02:14:40 INFO]: Using 4 threads for Netty based IO
# [02:14:40 INFO]: Hello Plugins!
# [02:14:41 INFO]: [WorldEdit] Loading WorldEdit v7.2.19+6642-415ef95
# [02:14:43 INFO]: Got request to register class com.sk89q.worldedit.bukkit.BukkitServerInterface with WorldEdit [com.sk89q.worldedit.extension.platform.PlatformManager@599194b1]
# [02:14:43 INFO]: [playit-gg] Loading playit-gg v0.1.4
# [02:14:43 INFO]: [LoginSecurity] Loading LoginSecurity v3.2.0
# [02:14:43 INFO]: [PlaceholderAPI] Loading PlaceholderAPI v2.11.5
# [02:14:43 INFO]: [ClearLag] Loading ClearLag v3.2.2
# [02:14:43 INFO]: [SternalBoard] Loading SternalBoard v2.2.8
# [02:14:43 INFO]: [PlayerTimeLimit] Loading PlayerTimeLimit v1.0
# [02:14:43 INFO]: [TAB] Loading TAB v4.1.2
# [02:14:43 INFO]: [Multiverse-Core] Loading Multiverse-Core v4.3.12
# [02:14:43 INFO]: [WorldGuard] Loading WorldGuard v7.0.9+5934e49
# [02:14:43 INFO]: [ConditionalEvents] Loading ConditionalEvents v4.48.1
# [02:14:43 INFO]: [ntdLuckyBlock] Loading ntdLuckyBlock v2.8.18
# [02:14:43 INFO]: [PvPManager] Loading PvPManager v3.17
# [02:14:43 INFO]: [WorldEdit] Enabling WorldEdit v7.2.19+6642-415ef95
# [02:14:43 INFO]: Registering commands with com.sk89q.worldedit.bukkit.BukkitServerInterface
# [02:14:43 INFO]: WEPIF: Using the Bukkit Permissions API.
# [02:14:45 INFO]: Using com.sk89q.worldedit.bukkit.adapter.impl.v1_20_R1.PaperweightAdapter as the Bukkit adapter
# [02:14:47 INFO]: [WorldEdit] ====================================================
# [02:14:47 INFO]: [WorldEdit]  WorldEdit works better if you use Paper
# [02:14:47 INFO]: [WorldEdit]  as your server software.
# [02:14:47 INFO]: [WorldEdit]
# [02:14:47 INFO]: [WorldEdit]  Paper offers significant performance improvements,
# [02:14:47 INFO]: [WorldEdit]  bug fixes, security enhancements and optional
# [02:14:47 INFO]: [WorldEdit]  features for server owners to enhance their server.
# [02:14:47 INFO]: [WorldEdit]
# [02:14:47 INFO]: [WorldEdit]  Paper includes Timings v2, which is significantly
# [02:14:47 INFO]: [WorldEdit]  better at diagnosing lag problems over v1.
# [02:14:47 INFO]: [WorldEdit]
# [02:14:47 INFO]: [WorldEdit]  All of your plugins should still work, and the
# [02:14:47 INFO]: [WorldEdit]  Paper community will gladly help you fix any issues.
# [02:14:47 INFO]: [WorldEdit]
# [02:14:47 INFO]: [WorldEdit]  Join the Paper Community @ https://papermc.io
# [02:14:47 INFO]: [WorldEdit] ====================================================
# [02:14:47 INFO]: Preparing level "world"
# [02:14:47 INFO]: Preparing start region for dimension minecraft:overworld
# [02:14:50 INFO]: Preparing spawn area: 0%
# [02:14:50 INFO]: Preparing spawn area: 0%
# [02:14:50 INFO]: Preparing spawn area: 0%
# [02:14:50 INFO]: Preparing spawn area: 0%
# [02:14:50 INFO]: Preparing spawn area: 0%
# [02:14:50 INFO]: Preparing spawn area: 0%
# [02:14:50 INFO]: Preparing spawn area: 0%
# [02:14:51 INFO]: Preparing spawn area: 23%
# [02:14:51 INFO]: Time elapsed: 3927 ms
# [02:14:51 INFO]: Preparing start region for dimension minecraft:the_nether
# [02:14:53 INFO]: Preparing spawn area: 0%
# [02:14:53 INFO]: Preparing spawn area: 0%
# [02:14:53 INFO]: Preparing spawn area: 0%
# [02:14:53 INFO]: Preparing spawn area: 0%
# [02:14:53 INFO]: Preparing spawn area: 69%
# [02:14:53 INFO]: Time elapsed: 2172 ms
# [02:14:53 INFO]: Preparing start region for dimension minecraft:the_end
# [02:14:54 INFO]: Preparing spawn area: 0%
# [02:14:54 INFO]: Preparing spawn area: 0%
# [02:14:54 INFO]: Preparing spawn area: 15%
# [02:14:55 INFO]: Time elapsed: 1354 ms
# [02:14:55 INFO]: [playit-gg] Enabling playit-gg v0.1.4
# [02:14:56 INFO]: secret key found, checking
# [02:14:56 INFO]: check secret
# [02:14:56 INFO]: [LoginSecurity] Enabling LoginSecurity v3.2.0
# [02:14:56 INFO]: [LoginSecurity] Loading base translations from "en_us"
# [02:14:56 INFO]: [LoginSecurity] Loading specified translations from "en_us"
# [02:14:56 INFO]: [LoginSecurity] Registering commands...
# [02:14:56 INFO]: [LoginSecurity] Registering listeners...
# [02:14:56 INFO]: [LoginSecurity] Using 1.12+ map captcha renderer
# [02:14:56 INFO]: [PlaceholderAPI] Enabling PlaceholderAPI v2.11.5
# [02:14:57 INFO]: found minecraft java tunnel: yahoo-ips.joinmc.link
# [02:14:57 INFO]: keys and tunnel setup
# [02:14:57 WARN]: Got IO error working with :control.playit.gg/2602:fbaf:804:0:0:0:0:1, error : java.net.SocketException: Network is unreachable
# [02:14:57 INFO]: [PlaceholderAPI] Fetching available expansion information...
# [02:14:57 INFO]: [PlaceholderAPI] Successfully registered internal expansion: mohist [1.20.1]
# [02:14:57 INFO]: Hook PlaceholderAPI!
# [02:14:57 INFO]: [ClearLag] Enabling ClearLag v3.2.2
# [02:14:57 INFO]: [ClearLag] Using version-adapter: LatestVersionAdapter
# [02:14:57 INFO]: request queued, waiting 1 second before resend
# [02:14:57 INFO]: [ClearLag] Loading modules...
# [02:14:57 WARN]: [ClearLag] Clearlag failed to use the internal TPS tracker during initialization. Reverted to estimation... (net.minecraft.server.v1_20_R1.MinecraftServer)
# [02:14:57 INFO]: [ClearLag] Modules enabed, loading config values
# [02:14:57 INFO]: [ClearLag] Modules have been loaded!
# [02:14:57 INFO]: [ClearLag] Clearlag is now enabled!
# [02:14:57 INFO]: [SternalBoard] Enabling SternalBoard v2.2.8
# [02:14:57 INFO]: [ClearLag] Checking for updates compatible with your bukkit version [1.20]...
# [02:14:57 INFO]: [PlayerTimeLimit] Enabling PlayerTimeLimit v1.0
# [02:14:57 INFO]: [TAB] Enabling TAB v4.1.2
# [02:14:57 INFO]: [ClearLag] No updates found!
# [02:14:58 INFO]: [PlaceholderAPI] Successfully registered internal expansion: tab [4.1.2]
# [02:14:58 INFO]: [TAB] §xEnabled in 411ms
# [02:14:58 INFO]: [Multiverse-Core] Enabling Multiverse-Core v4.3.12
# [02:14:58 WARN]: [Multiverse-Core] "Multiverse-Core v4.3.12" has registered a listener for org.bukkit.event.entity.EntityCreatePortalEvent on method "public void com.onarandombox.MultiverseCore.listeners.MVPortalListener.entityPortalCreate(org.bukkit.event.entity.EntityCreatePortalEvent)", but the event is Deprecated. "Server performance will be affected"; please notify the authors [dumptruckman, Rigby, fernferret, lithium3141, main--].
# [02:14:58 INFO]: [Multiverse-Core] We are aware of the warning about the deprecated event. There is no alternative that allows us to do what we need to do and performance impact is negligible. It is safe to ignore.
# [02:14:58 WARN]: [Multiverse-Core] WorldManager: Can't load this world because the folder was deleted/moved: debate
# [02:14:58 WARN]: [Multiverse-Core] Use '/mv remove' to remove it from the config!
# [02:14:58 INFO]: Preparing start region for dimension minecraft:event
# [02:15:01 INFO]: Preparing spawn area: 0%
# [02:15:01 INFO]: Preparing spawn area: 0%
# [02:15:01 INFO]: Preparing spawn area: 0%
# [02:15:01 INFO]: Preparing spawn area: 0%
# [02:15:01 INFO]: Preparing spawn area: 0%
# [02:15:01 INFO]: Preparing spawn area: 0%
# [02:15:01 INFO]: Preparing spawn area: 0%
# [02:15:02 INFO]: Preparing spawn area: 0%
# [02:15:02 INFO]: Preparing spawn area: 54%
# [02:15:02 INFO]: Time elapsed: 4245 ms
# [02:15:03 INFO]: [Multiverse-Core] 4 - World(s) loaded.
# [02:15:03 WARN]: [Multiverse-Core] Buscript failed to load! The script command will be disabled! If you would like not to see this message, use `/mv conf enablebuscript false` to disable Buscript from loading.
# [02:15:03 INFO]: [Multiverse-Core] Version 4.3.12 (API v24) Enabled - By dumptruckman, Rigby, fernferret, lithium3141 and main--
# [02:15:03 INFO]: [WorldGuard] Enabling WorldGuard v7.0.9+5934e49
# [02:15:03 INFO]: [WorldGuard] (world) TNT ignition is PERMITTED.
# [02:15:03 INFO]: [WorldGuard] (world) Lighters are PERMITTED.
# [02:15:03 INFO]: [WorldGuard] (world) Lava fire is PERMITTED.
# [02:15:03 INFO]: [WorldGuard] (world) Fire spread is UNRESTRICTED.
# [02:15:03 INFO]: [WorldGuard] Loaded configuration for world 'world'
# [02:15:03 INFO]: [WorldGuard] (DIM-1) TNT ignition is PERMITTED.
# [02:15:03 INFO]: [WorldGuard] (DIM-1) Lighters are PERMITTED.
# [02:15:03 INFO]: [WorldGuard] (DIM-1) Lava fire is PERMITTED.
# [02:15:03 INFO]: [WorldGuard] (DIM-1) Fire spread is UNRESTRICTED.
# [02:15:03 INFO]: [WorldGuard] Loaded configuration for world 'DIM-1'
# [02:15:03 INFO]: [WorldGuard] (DIM1) TNT ignition is PERMITTED.
# [02:15:03 INFO]: [WorldGuard] (DIM1) Lighters are PERMITTED.
# [02:15:03 INFO]: [WorldGuard] (DIM1) Lava fire is PERMITTED.
# [02:15:03 INFO]: [WorldGuard] (DIM1) Fire spread is UNRESTRICTED.
# [02:15:03 INFO]: [WorldGuard] Loaded configuration for world 'DIM1'
# [02:15:03 INFO]: [WorldGuard] (event) TNT ignition is PERMITTED.
# [02:15:03 INFO]: [WorldGuard] (event) Lighters are PERMITTED.
# [02:15:03 INFO]: [WorldGuard] (event) Lava fire is PERMITTED.
# [02:15:03 INFO]: [WorldGuard] (event) Fire spread is UNRESTRICTED.
# [02:15:03 INFO]: [WorldGuard] Loaded configuration for world 'event'
# [02:15:03 INFO]: [WorldGuard] Loading region data...
# [02:15:03 INFO]: [ConditionalEvents] Enabling ConditionalEvents v4.48.1
# [02:15:04 INFO]: [PlaceholderAPI] Successfully registered internal expansion: conditionalevents [4.48.1]
# [02:15:04 INFO]: [ConditionalEvents] Has been enabled! Version: 4.48.1
# [02:15:04 INFO]: [ConditionalEvents] Thanks for using my plugin!   ~Ajneb97
# [02:15:04 INFO]: There is a new version available. (4.47.4)
# [02:15:04 INFO]: You can download it at: https://modrinth.com/plugin/conditionalevents
# [02:15:04 INFO]: [ntdLuckyBlock] Enabling ntdLuckyBlock v2.8.18
# [02:15:04 INFO]: [ntdLuckyBlock] Starting LuckyBlock (ntdLuckyBlock) v2.8.18, build121(12/02/2024), free
# [02:15:04 INFO]: [ntdLuckyBlock]   ╭╮╱╱╭╮╱╭┳━━━┳╮╭━┳╮╱╱╭┳━━╮╭╮╱╱╭━━━┳━━━┳╮╭━╮
# [02:15:04 INFO]: [ntdLuckyBlock]   ┃┃╱╱┃┃╱┃┃╭━╮┃┃┃╭┫╰╮╭╯┃╭╮┃┃┃╱╱┃╭━╮┃╭━╮┃┃┃╭╯
# [02:15:04 INFO]: [ntdLuckyBlock]   ┃┃╱╱┃┃╱┃┃┃╱╰┫╰╯╯╰╮╰╯╭┫╰╯╰┫┃╱╱┃┃╱┃┃┃╱╰┫╰╯╯
# [02:15:04 INFO]: [ntdLuckyBlock]   ┃┃╱╭┫┃╱┃┃┃╱╭┫╭╮┃╱╰╮╭╯┃╭━╮┃┃╱╭┫┃╱┃┃┃╱╭┫╭╮┃
# [02:15:04 INFO]: [ntdLuckyBlock]   ┃╰━╯┃╰━╯┃╰━╯┃┃┃╰╮╱┃┃╱┃╰━╯┃╰━╯┃╰━╯┃╰━╯┃┃┃╰╮
# [02:15:04 INFO]: [ntdLuckyBlock]   ╰━━━┻━━━┻━━━┻╯╰━╯╱╰╯╱╰━━━┻━━━┻━━━┻━━━┻╯╰━╯ NTD
# [02:15:04 INFO]: [ntdLuckyBlock]           Made with love by DenBeKKer
# [02:15:04 INFO]: [ntdLuckyBlock]
# [02:15:04 INFO]: [ntdLuckyBlock] =-= SUPPORT § BUG REPORTING § FEATURE REQUESTING =-=
# [02:15:04 INFO]: [ntdLuckyBlock]  > Discord - https://discord.gg/vbYW3sperj
# [02:15:04 INFO]: [ntdLuckyBlock]  > Vkontakte - https://vk.com/danirodplay (Rus)
# [02:15:04 INFO]: [ntdLuckyBlock] =-= SUPPORT § BUG REPORTING § FEATURE REQUESTING =-=
# [02:15:04 INFO]: [ntdLuckyBlock] Loaded main material version
# [02:15:04 INFO]: [ntdLuckyBlock] Loading NMS for your platform (1.20.1-580 (MC: 1.20.1), v1_20_R1)...
# [02:15:04 INFO]: [ntdLuckyBlock] Loading language file "en" by DenBeKKer
# [02:15:04 INFO]: [ntdLuckyBlock] WorldEdit connected
# [02:15:04 INFO]: [ntdLuckyBlock] WorldGuard connected
# [02:15:04 INFO]: [ntdLuckyBlock] Vault not found
# [02:15:04 INFO]: [ntdLuckyBlock] TokenManager not found
# [02:15:04 INFO]: [ntdLuckyBlock] SlimeFun not found
# [02:15:04 INFO]: [ntdLuckyBlock] Found 2/5 compatible plugins
# [02:15:04 INFO]: [ntdLuckyBlock] Loading system...
# [02:15:04 INFO]: [ntdLuckyBlock] Loaded 11 internal custom items...
# [02:15:04 INFO]: [ntdLuckyBlock] Loaded 11 custom items... (Total)
# [02:15:04 WARN]: Initializing Legacy Material Support. Unless you have legacy plugins and/or data this is a bug!
# [02:15:06 INFO]: [ntdLuckyBlock] Loaded 16 luckyblock types...
# [02:15:06 INFO]: [ntdLuckyBlock] System loaded (took 2347 ms)...
# [02:15:06 INFO]: [ntdLuckyBlock] If you love my plugin, support me with 5 stars review(https://www.spigotmc.org/resources/92026/) or consider to purchase premium plugin version (https://www.spigotmc.org/resources/94872/)
# [02:15:06 INFO]: [ntdLuckyBlock] Enabled (took 2538 ms)...
# [02:15:06 INFO]: [PvPManager] Enabling PvPManager v3.17
# [02:15:06 INFO]: [PvPManager] Using player nametags: true
# [02:15:06 INFO]: [PvPManager] Connected to SQLITE database successfully
# [02:15:06 INFO]: [PvPManager] Players stored: 1
# [02:15:06 INFO]: [PvPManager] WorldGuard Found! Enabling Support For WorldGuard Regions
# [02:15:06 WARN]: [PvPManager] Vault not found! Features requiring Vault won't work!
# [02:15:06 INFO]: [PvPManager] PlaceholderAPI Found! Hooked successfully
# [02:15:06 INFO]: [PlaceholderAPI] Successfully registered internal expansion: pvpmanager [3.17]
# [02:15:07 INFO]: [PvPManager] PvPManager v3.17 enabled (374 ms)
# [02:15:07 INFO]: [Mohist] Enabling Mohist v1.20.1
# [02:15:07 INFO]: Server permissions file permissions.yml is empty, ignoring it
# [02:15:07 INFO]: [PlaceholderAPI] Placeholder expansion registration initializing...
# [02:15:07 INFO]: Done (20.061s)! For help, type "help"
# [02:15:07 INFO]: Successfully initialized permission handler forge:default_handler
# [02:15:07 INFO]: Forwarding forge permission[forge:default_handler] to bukkit[mohist:permission]
# [02:15:07 WARN]: [voicechat] Running in offline mode - Voice chat encryption is not secure!
# [02:15:07 INFO]: [voicechat] Voice chat server started at port 24454
# [02:15:07 INFO]: [PlaceholderAPI] Successfully registered external expansion: objective [4.2.0]
# [02:15:07 INFO]: 1 placeholder hook(s) registered!
# [02:15:07 INFO]: [PvPManager] Checking for updates...
# [02:15:07 INFO]: [PvPManager] No update found
# [02:15:25 INFO]: got new client: NewClient{connectAddr=209.25.143.181:60642, peerAddr=172.59.122.41:21396, claimAddress=209.25.140.2:43784, claimToken=[44, 0, 60, -47, 25, -113, -75, -20, -30, -84, 59, 122, 41, 83, -108, 71, -90, 12, -77, -85, 8, 101, -33, -24, -67, 0, 0, 0, 0, 0, 6, -58, 27, 0, 0, 0, 0, 0, 46, -67, -8, 84, -77, -85, 8, 0, 0, 0, 0, 28, 0, 0, 0, 0, 0, 0, 0, 1, 0, 1, -4, 28, -50, 39, 3, 15, 78, -21, 114, -92, -28, -69, 82, -87, -8, 39], tunnelServerId=1, dataCenterId=28}
# [02:15:25 INFO]: starting tcp tunnel for client
# [02:15:25 INFO]: start connection to /209.25.140.2:43784 to claim client
# [02:15:25 INFO]: connected to tunnel server, sending claim token
# [02:15:25 INFO]: claim token sent
# [02:15:25 INFO]: connection to tunnel server has been established
# [02:15:25 INFO]: Reflect: ReflectionHelper{ServerConnection=class net.minecraft.server.network.ServerConnectionListener, LegacyPingHandler=class net.minecraft.server.network.LegacyQueryHandler, MinecraftServer=class net.minecraft.server.MinecraftServer, PacketSplitter=class net.minecraft.network.Varint21FrameDecoder, PacketDecoder=class net.minecraft.network.PacketDecoder, EnumProtocolDirection=class net.minecraft.network.protocol.PacketFlow, PacketPrepender=class net.minecraft.network.Varint21LengthFieldPrepender, PacketEncoder=class net.minecraft.network.PacketEncoder, NetworkManagerServer=class net.minecraft.network.RateKickingConnection, NetworkManager=class net.minecraft.network.Connection, HandshakeListener=class net.minecraft.server.network.ServerHandshakePacketListenerImpl, PacketListener=interface net.minecraft.network.PacketListener, CraftServer=null}
# [02:15:25 INFO]: failed to get Minecraft server from Bukkit.getServer()
# [02:15:25 INFO]: connecting to minecraft server at localhost/127.0.0.1:25565
# [02:15:25 INFO]: connected to local minecraft server
# [02:15:30 INFO]: vortexfer_ joined the game
# [02:15:30 INFO]: vortexfer_[/127.0.0.1:43120] logged in with entity id 152 at ([world]2.4110145661383005, 102.0, 1.9088480425760976)
# [02:18:48 WARN]: An exceptionCaught() event was fired, and it reached at the tail of the pipeline. It usually means the last handler in the pipeline did not handle the exception.
# java.net.SocketException: Connection reset
# 	at sun.nio.ch.SocketChannelImpl.throwConnectionReset(SocketChannelImpl.java:401) ~[?:?]
# 	at sun.nio.ch.SocketChannelImpl.read(SocketChannelImpl.java:434) ~[?:?]
# 	at io.netty.buffer.PooledByteBuf.setBytes(PooledByteBuf.java:258) ~[netty-buffer-4.1.82.Final.jar%23166!/:4.1.82.Final]
# 	at io.netty.buffer.AbstractByteBuf.writeBytes(AbstractByteBuf.java:1132) ~[netty-buffer-4.1.82.Final.jar%23166!/:4.1.82.Final]
# 	at io.netty.channel.socket.nio.NioSocketChannel.doReadBytes(NioSocketChannel.java:357) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.AbstractNioByteChannel$NioByteUnsafe.read(AbstractNioByteChannel.java:151) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKey(NioEventLoop.java:788) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeysOptimized(NioEventLoop.java:724) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeys(NioEventLoop.java:650) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:562) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997) ~[netty-common-4.1.82.Final.jar%23168!/:4.1.82.Final]
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74) ~[netty-common-4.1.82.Final.jar%23168!/:4.1.82.Final]
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30) ~[netty-common-4.1.82.Final.jar%23168!/:4.1.82.Final]
# 	at java.lang.Thread.run(Thread.java:1583) [?:?]
# [02:18:48 WARN]: failed to send data to tunnel
# [02:18:48 INFO]: vortexfer_ lost connection: Disconnected
# [02:18:48 INFO]: [voicechat] Disconnecting client vortexfer_
# [02:18:48 INFO]: vortexfer_ left the game
# [02:18:58 INFO]: send keep alive
# [02:22:59 INFO]: send keep alive
# [02:23:24 INFO]: got new client: NewClient{connectAddr=209.25.143.181:60642, peerAddr=172.59.122.41:25039, claimAddress=209.25.140.2:43784, claimToken=[44, 0, 60, -47, 25, -113, -75, -20, -30, -84, 59, 122, 41, 97, -49, -124, -97, -91, -47, -85, 8, 101, -33, -22, -100, 0, 0, 0, 0, 0, 6, -58, 27, 0, 0, 0, 0, 0, 46, -67, -8, -45, -47, -85, 8, 0, 0, 0, 0, 28, 0, 0, 0, 0, 0, 0, 0, 1, 0, 1, 115, -89, -105, -64, -59, -58, -53, -25, -110, -96, 27, -7, -79, -123, 41, -27], tunnelServerId=1, dataCenterId=28}
# [02:23:24 INFO]: starting tcp tunnel for client
# [02:23:24 INFO]: start connection to /209.25.140.2:43784 to claim client
# [02:23:24 INFO]: connected to tunnel server, sending claim token
# [02:23:24 INFO]: claim token sent
# [02:23:24 INFO]: connection to tunnel server has been established
# [02:23:24 INFO]: Reflect: ReflectionHelper{ServerConnection=class net.minecraft.server.network.ServerConnectionListener, LegacyPingHandler=class net.minecraft.server.network.LegacyQueryHandler, MinecraftServer=class net.minecraft.server.MinecraftServer, PacketSplitter=class net.minecraft.network.Varint21FrameDecoder, PacketDecoder=class net.minecraft.network.PacketDecoder, EnumProtocolDirection=class net.minecraft.network.protocol.PacketFlow, PacketPrepender=class net.minecraft.network.Varint21LengthFieldPrepender, PacketEncoder=class net.minecraft.network.PacketEncoder, NetworkManagerServer=class net.minecraft.network.RateKickingConnection, NetworkManager=class net.minecraft.network.Connection, HandshakeListener=class net.minecraft.server.network.ServerHandshakePacketListenerImpl, PacketListener=interface net.minecraft.network.PacketListener, CraftServer=null}
# [02:23:24 INFO]: failed to get Minecraft server from Bukkit.getServer()
# [02:23:24 INFO]: connecting to minecraft server at localhost/127.0.0.1:25565
# [02:23:24 INFO]: connected to local minecraft server
# [02:23:26 INFO]: got new client: NewClient{connectAddr=209.25.143.181:60642, peerAddr=172.59.122.41:48625, claimAddress=209.25.140.2:43784, claimToken=[44, 0, 60, -47, 25, -113, -75, -20, -30, -84, 59, 122, 41, -67, -15, -105, -97, -113, 90, -85, 8, 101, -33, -22, -98, 0, 0, 0, 0, 0, 6, -58, 27, 0, 0, 0, 0, 0, 46, -67, -8, -45, 90, -85, 8, 0, 0, 0, 0, 28, 0, 0, 0, 0, 0, 0, 0, 1, 0, 1, 32, -88, 0, -96, -62, -71, 113, 59, -100, 44, -30, 19, 75, -16, 89, -43], tunnelServerId=1, dataCenterId=28}
# [02:23:26 INFO]: starting tcp tunnel for client
# [02:23:26 INFO]: start connection to /209.25.140.2:43784 to claim client
# [02:23:26 INFO]: connected to tunnel server, sending claim token
# [02:23:26 INFO]: claim token sent
# [02:23:26 INFO]: connection to tunnel server has been established
# [02:23:26 INFO]: Reflect: ReflectionHelper{ServerConnection=class net.minecraft.server.network.ServerConnectionListener, LegacyPingHandler=class net.minecraft.server.network.LegacyQueryHandler, MinecraftServer=class net.minecraft.server.MinecraftServer, PacketSplitter=class net.minecraft.network.Varint21FrameDecoder, PacketDecoder=class net.minecraft.network.PacketDecoder, EnumProtocolDirection=class net.minecraft.network.protocol.PacketFlow, PacketPrepender=class net.minecraft.network.Varint21LengthFieldPrepender, PacketEncoder=class net.minecraft.network.PacketEncoder, NetworkManagerServer=class net.minecraft.network.RateKickingConnection, NetworkManager=class net.minecraft.network.Connection, HandshakeListener=class net.minecraft.server.network.ServerHandshakePacketListenerImpl, PacketListener=interface net.minecraft.network.PacketListener, CraftServer=null}
# [02:23:26 INFO]: failed to get Minecraft server from Bukkit.getServer()
# [02:23:26 INFO]: connecting to minecraft server at localhost/127.0.0.1:25565
# [02:23:26 INFO]: connected to local minecraft server
# [02:23:29 INFO]: vortexfer_ joined the game
# [02:23:29 INFO]: vortexfer_[/127.0.0.1:54538] logged in with entity id 155 at ([world]-1.4429714227765686, 102.0, -0.7318729192500307)
# [02:24:00 INFO]: vortexfer_ issued server command: /pvp off
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [02:24:32 INFO]: vortexfer_ issued server command: //wand
# [02:25:02 INFO]: vortexfer_ issued server command: //copy
# [02:25:12 INFO]: vortexfer_ issued server command: /mv tp evento
# [02:25:17 INFO]: vortexfer_ issued server command: /mv list
# [02:25:26 INFO]: vortexfer_ issued server command: /mv tp event
# [02:25:36 INFO]: vortexfer_ issued server command: /gamemode creative
# [02:25:36 INFO]: [vortexfer_: Set own game mode to Creative Mode]
# [02:25:57 INFO]: vortexfer_ issued server command: //paste
# [02:26:59 INFO]: send keep alive
# [02:30:57 INFO]: vortexfer_ has made the advancement [Monster Hunter]
# [02:30:59 INFO]: send keep alive
# [02:31:27 INFO]: vortexfer_ issued server command: /mv tp debate
# [02:31:37 INFO]: vortexfer_ issued server command: /mv delete debate
# [02:31:41 INFO]: vortexfer_ issued server command: /mv confirm
# [02:31:41 WARN]: [Multiverse-Core] WorldManager: Can't load this world because the folder was deleted/moved: debate
# [02:31:41 WARN]: [Multiverse-Core] Use '/mv remove' to remove it from the config!
# [02:32:01 INFO]: vortexfer_ issued server command: /mv remove
# [02:32:07 INFO]: vortexfer_ issued server command: /mv remove debate
# [02:32:07 INFO]: [Multiverse-Core] World 'debate' was removed from config.yml
# [02:32:59 INFO]: vortexfer_ issued server command: /luckyblock
# [02:33:39 INFO]: vortexfer_ issued server command: /papi ecloud download timelimit
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [02:35:00 INFO]: send keep alive
# [02:39:00 INFO]: send keep alive
# [02:43:01 INFO]: send keep alive
# [02:43:08 WARN]: failed to send data to tunnel
# [02:43:08 WARN]: failed to send data to tunnel
# [02:43:08 INFO]: vortexfer_ lost connection: Disconnected
# [02:43:08 INFO]: [voicechat] Disconnecting client vortexfer_
# [02:43:08 INFO]: vortexfer_ left the game
# [02:43:10 INFO]: got new client: NewClient{connectAddr=209.25.143.181:60642, peerAddr=172.59.122.41:55300, claimAddress=209.25.140.2:43784, claimToken=[44, 0, 60, -47, 25, -113, -75, -20, -30, -84, 59, 122, 41, -40, 4, -51, -82, -104, 105, -85, 8, 101, -33, -17, 62, 0, 0, 0, 0, 0, 6, -58, 27, 0, 0, 0, 0, 0, 46, -67, -8, -128, 105, -85, 8, 0, 0, 0, 0, 28, 0, 0, 0, 0, 0, 0, 0, 1, 0, 1, 111, 117, 8, -88, 41, 63, 68, 109, -44, 49, -9, -60, 16, 98, 122, -14], tunnelServerId=1, dataCenterId=28}
# [02:43:10 INFO]: starting tcp tunnel for client
# [02:43:10 INFO]: start connection to /209.25.140.2:43784 to claim client
# [02:43:10 INFO]: connected to tunnel server, sending claim token
# [02:43:10 INFO]: claim token sent
# [02:43:10 INFO]: connection to tunnel server has been established
# [02:43:10 INFO]: Reflect: ReflectionHelper{ServerConnection=class net.minecraft.server.network.ServerConnectionListener, LegacyPingHandler=class net.minecraft.server.network.LegacyQueryHandler, MinecraftServer=class net.minecraft.server.MinecraftServer, PacketSplitter=class net.minecraft.network.Varint21FrameDecoder, PacketDecoder=class net.minecraft.network.PacketDecoder, EnumProtocolDirection=class net.minecraft.network.protocol.PacketFlow, PacketPrepender=class net.minecraft.network.Varint21LengthFieldPrepender, PacketEncoder=class net.minecraft.network.PacketEncoder, NetworkManagerServer=class net.minecraft.network.RateKickingConnection, NetworkManager=class net.minecraft.network.Connection, HandshakeListener=class net.minecraft.server.network.ServerHandshakePacketListenerImpl, PacketListener=interface net.minecraft.network.PacketListener, CraftServer=null}
# [02:43:10 INFO]: failed to get Minecraft server from Bukkit.getServer()
# [02:43:10 INFO]: connecting to minecraft server at localhost/127.0.0.1:25565
# [02:43:10 INFO]: connected to local minecraft server
# >
